# %% [markdown]
# imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

tor
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0         192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...
# 1         193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...
# 2         195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...
# 3         196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...
# 4         197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 68696  621922  2022   9  28  2022-09-28  13:32:00   3  FL   12    0  ...
# 68697  621923  2022   9  30  2022-09-30  10:25:00   3  NC   37    0  ...
# 68698  621924  2022   9  30  2022-09-30  13:22:00   3  NC   37    0  ...
# 68699  621900  2022   9   4  2022-09-04  15:44:00   3  OH   39    0  ...
# 68700  621901  2022   9   9  2022-09-09  23:21:00   3  SC   45    0  ...
#
#          len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# ...

# %% [markdown]
# Figure 1

# %%
tor.st.value_counts(ascending=True)[43:].plot(kind='barh',zorder=5)
plt.title("Top 10 US States by Tornado Count (1950-2020)")
plt.xlabel("Number of Tornadoes")
plt.ylabel("State")
plt.grid()

# %%
tor2000_2020 = tor[tor.yr >= 2000]
tor2000_2020.st.value_counts(ascending=True)[43:].plot(kind='barh',zorder=5)
plt.title("Top 10 US States by Tornado Count (2000-2020)")
plt.xlabel("Number of Tornadoes")
plt.ylabel("State")
plt.grid()
